# %%
import os
import re
import pandas as pd

# %%
experiments_path = 'experiments'

# %%
def find_value(string, regex):
    try:
        return re.findall(regex, string)[0]
    except:
        return None
    
def read_results(filepath):
    results = []
    with open(filepath) as f:
        for i in range(5):
            results.append(float(f.readline()))
    return results

# %%
df = pd.DataFrame()
for root, dirs, files in os.walk(experiments_path):
    for name in files:
        if name == 'test_results.txt':
            print(os.path.join(root, name))
            enemy = find_value(root, r'enemy(\d)_')
            tournament = find_value(root, r'tournament([A-Za-z]+)')
            mating = find_value(root, r'mating(\d)_')
            pop_size = find_value(root, r'pop([\d]+)_')
            patience = find_value(root, r'patience([\d]+)_')
            DPR = find_value(root, r'DPR(\d\.\d)_')
            DRWRP = find_value(root, r'DPR(\d\.\d)_')
            mut = find_value(root, r'mut[A-Za-z]+')
            mu = find_value(root, r'mu(\d)sigma')
            sigma = find_value(root, r'sigma(\d)prob')
            mut_prob = find_value(root, r'prob([\d]{2,})_') 
            crossover = find_value(root, r'cx[A-Za-z]+')
            results = read_results(os.path.join(root, name))
            df.loc[len(df), ['enemy', 'tournament', 'mating', 'population_size', 'patience', 'DPR', 'DRWRP', 'mut', 'mu','sigma', 'mut_prob', 'crossover', 'test1', 'test2', 'test3', 'test4', 'test5']] = enemy, tournament, mating, pop_size, patience, DPR, DRWRP, mut, mu,sigma, mut_prob, crossover, *results
# Out:
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_10\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.9_mutGaus_mu0sigma1prob03_cxOnePoint_1\test_results.txt
# experiments\enemy1_mating4_pop100_patience3_DPR0.4_DRWRP0.9_mutGaus_mu0sigma1prob03_cxOnePoint_2\test_results.txt
# experiments\enemy1_mating4_pop70_patience2_DPR0.3_DRWRP0.9_mutGaus_mu0sigma1prob03_cxOnePoint_1\test_results.txt
# experiments\enemy1_tournamentselProportional_mating10_pop30_patience9_DPR0.2322873439941655_DRWRP0.00813590142365872_mutGaus_mu0sigma1prob0.3_cxUniform_hyperopt\test_results.txt
# experiments\enemy1_tournamentselProportional_mating2_pop100_patience16_DPR0.7952949394068969_DRWRP0.5883631946100971_mutGaus_mu0sigma1prob0.3_cxUniform_hyperopt\test_results.txt
# experiments\enemy1_tournamentselProportional_mating2_pop30_patience5_DPR0.5711363431535358_DRWRP0.46362442635573275_mutGaus_mu0sigma1prob0.3_cxUniform_hyperopt\test_results.txt
# experiments\enemy1_tournamentselProportional_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy1_tournamentselTournament_mating10_pop100_patience18_DPR0.7192988548989729_DRWRP0.9691061184996076_mutGaus_mu0sigma1prob03_cxUniform_hyperopt\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop100_patience4_DPR0.3_DRWRP0.9_mutGaus_mu0sigma1prob03_cxOnePoint_hyperopt\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop30_patience4_DPR0.3_DRWRP0.9_mutGaus_mu0sigma1prob03_cxOnePoint_hyperopt\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_10\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy1_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy1_tournamentselTournament_mating6_pop30_patience19_DPR0.9159882362590192_DRWRP0.6488539169090465_mutGaus_mu0sigma1prob0.2_cxUniform_hyperopt\test_results.txt
# experiments\enemy1_tournamentselTournament_mating7_pop100_patience2_DPR0.355290335083546_DRWRP0.8134286480302781_mutGaus_mu0sigma1prob03_cxUniform_hyperopt\test_results.txt
# experiments\enemy1_tournamentselTournament_mating7_pop30_patience17_DPR0.6131728661296278_DRWRP0.45898375912875056_mutGaus_mu0sigma1prob03_cxUniform_hyperopt\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_10\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy2_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_10\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy2_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_10\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy3_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_10\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy3_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy4_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy4_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy4_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy4_mating4_pop100_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_10\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy4_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_2\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_3\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_4\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_5\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_6\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_7\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_8\test_results.txt
# experiments\enemy5_tournamentselTournament_mating4_pop70_patience4_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_9\test_results.txt
# experiments\enemy6_tournamentselTournament_mating4_pop70_patience3_DPR0.4_DRWRP0.85_mutGaus_mu0sigma1prob03_cxUniform_1\test_results.txt

# %%
df['enemy'].value_counts()
# Out:
# 1    34
# 2    20
# 3    20
# 4    14
# 5     9
# 6     1
# Name: enemy, dtype: int64

# %%
df['mean_test'] = df[[c for c in df.columns if 'test' in c]].mean(axis=1)

# %%
hypers = [c for c in df.columns if 'test' not in c]
df.groupby(hypers)['mean_test'].mean().to_frame()
# Out:
#                                                                                                       mean_test
# enemy tournament      mating population_size patience DPR DRWRP mut     mu sigma mut_prob crossover
# 1     selProportional 4      100             3        0.4 0.4   mutGaus 0  1     03       cxUniform   48.348598
#       selTournament   4      100             3        0.4 0.4   mutGaus 0  1     03       cxUniform   30.809106
#                                              4        0.3 0.3   mutGaus 0  1     03       cxOnePoint  26.857530
#                              30              4        0.3 0.3   mutGaus 0  1     03       cxOnePoint  14.805737
#                              70              4        0.4 0.4   mutGaus 0  1     03       cxUniform   41.781621
# 2     selTournament   4      70              4        0.4 0.4   mutGaus 0  1     03       cxUniform   84.775128
# 3     selTournament   4      70              4        0.4 0.4   mutGaus 0  1     03       cxUniform   66.868829
# 4     selTournament   4      70              4        0.4 0.4   mutGaus 0  1     03       cxUniform   53.321090
# 5     selTournament   4      70              4        0.4 0.4   mutGaus 0  1     03       cxUniform   86.352474
# 6     selTournament   4      70              3        0.4 0.4   mutGaus 0  1     03       cxUniform   49.501245
